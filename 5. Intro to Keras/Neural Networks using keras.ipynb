# %%
import numpy as np

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
n_pts = 500
np.random.seed(0)
Xa = np.array([np.random.normal(13, 2, n_pts),
               np.random.normal(12, 2, n_pts)]).T
Xb = np.array([np.random.normal(8, 2, n_pts),
               np.random.normal(6, 2, n_pts)]).T

X = np.vstack((Xa, Xb))
Y = np.matrix(np.append(np.zeros(n_pts), np.ones(n_pts))).T

plt.scatter(X[:n_pts,0], X[:n_pts,1])
plt.scatter(X[n_pts:,0], X[n_pts:,1])

# %%
model = Sequential()
model.add(Dense(units=1, input_shape=(2,), activation='sigmoid'))
adam=Adam(lr=0.1) #lr is the learning rate

#To train our model to classify the data we want , we need to compile the model
model.compile(adam, loss='binary_crossentropy',metrics=['accuracy']) # Since we want to classify between two distinct object we will use binary cross entropy
# for more than 2 objects use categorical_crossentropy
h=model.fit(x=X, y=Y,verbose=1,batch_size=50, epochs=500,shuffle='true') #Specify the labels
#Here X is the input and Y is the label
# Out:
# Epoch 1/500
# 20/20 [==============================] - 0s 999us/step - loss: 0.7983 - accuracy: 0.6700
# Epoch 2/500
# 20/20 [==============================] - 0s 1ms/step - loss: 0.5338 - accuracy: 0.7450
# Epoch 3/500
# 20/20 [==============================] - 0s 1ms/step - loss: 0.3728 - accuracy: 0.8880
# Epoch 4/500
# 20/20 [==============================] - 0s 1ms/step - loss: 0.3083 - accuracy: 0.9310
# Epoch 5/500
# 20/20 [==============================] - 0s 996us/step - loss: 0.2608 - accuracy: 0.9520
# Epoch 6/500
# 20/20 [==============================] - 0s 1ms/step - loss: 0.2269 - accuracy: 0.9480
# Epoch 7/500
# 20/20 [==============================] - 0s 1ms/step - loss: 0.2069 - accuracy: 0.9610
# Epoch 8/500
# 20/20 [==============================] - 0s 1ms/step - loss: 0.1911 - accuracy: 0.9570
# Epoch 9/500
# 20/20 [==============================] - 0s 1ms/step - loss: 0.1740 - accuracy: 0.9650
# Epoch 10/500
# ...

# %%
plt.plot(h.history['accuracy'])
plt.title('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Accuracy'])

# %%
plt.plot(h.history['loss'])
plt.title('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Accuracy'])

# %%
def plot_decision_boundary(X,Y, model):
    x_span=np.linspace(min(X[:,0])-1,max(X[:,0])+1)
    y_span=np.linspace(min(X[:,1])-1,max(X[:,1])+1)
    xx,yy=np.meshgrid(x_span,y_span)
    
    xx_,yy_=xx.ravel(),yy.ravel()
    
    grid=np.c_[xx_,yy_]
    
    pred_func=model.predict(grid)
    z=pred_func.reshape(xx.shape)
    plt.contourf(xx,yy,z)
    plt.scatter(X[:n_pts,0], X[:n_pts,1])
    plt.scatter(X[n_pts:,0], X[n_pts:,1])

# %%
plot_decision_boundary(X,Y,model)

# %%
#Lets now predict the new input data without labels
x=7.5
y=5

point=np.array([[x,y]])
prediction=model.predict(point)

plt.plot([x],[y], marker='o', markersize=10,color='red')
print("Prediction is :",prediction)
# Out:
# Prediction is : [[0.99999166]]
